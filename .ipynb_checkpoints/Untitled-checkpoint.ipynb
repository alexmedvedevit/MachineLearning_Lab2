# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn import svm

plt.style.use('ggplot')

# %%
df = pd.read_csv('breast_cancer.csv')

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    ('std_scaler',StandardScaler())
])

# %%
diagnosis = df["diagnosis"].map({ 'B': 0, 'M': 1 })
diagnosis
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
data = df.drop('diagnosis',axis=1)
data = data.drop('Unnamed: 32',axis=1)
data = pd.get_dummies(data)
data
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#Линейная модель

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(data,diagnosis)
# Out:
# LinearRegression()

# %%
some_data = data.tail(5)
some_data
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424        21.56         22.39          142.00     1479.0
# 565  926682        20.13         28.25          131.20     1261.0
# 566  926954        16.60         28.08          108.30      858.1
# 567  927241        20.60         29.33          140.10     1265.0
# 568   92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
some_diagnosis = diagnosis.tail(5)
some_diagnosis
# Out:
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, dtype: int64

# %%
pipeline.fit(data)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('std_scaler', StandardScaler())])

# %%
data_prepared_some = pipeline.transform(some_data)
data_prepared_some
# Out:
# array([[-0.23573171,  2.11099466,  0.7214726 ,  2.06078553,  2.34385595,
#          1.04184206,  0.21906045,  1.94728461,  2.32096456, -0.31258877,
#         -0.93102704,  2.78207994,  0.07102535,  2.37958283,  2.60418662,
#          1.08638441,  0.19180514,  0.66600137,  2.06717774, -1.13841627,
#          0.16797996,  1.9011854 ,  0.11769971,  1.75256261,  2.01530079,
#          0.37836537, -0.27331771,  0.66451226,  1.62915116, -1.36015829,
#         -0.70909067],
#        [-0.23572964,  1.70485436,  2.08513394,  1.61593137,  1.72384158,
#          0.10245823, -0.01783304,  0.69304299,  1.26366923, -0.21766424,
#         -1.0586114 ,  1.30049923,  2.26093843,  1.15685722,  1.29156462,
#         -0.42401016, -0.0697579 ,  0.25220172,  0.80843074, -0.1891608 ,
#         -0.49055563,  1.53672015,  2.04739864,  1.42193981,  1.49495863,
#         -0.69123037, -0.39482039,  0.23657316,  0.73382724, -0.53185462,
#         -0.97397828],
# ...

# %%
print("Прогнозы:", model.predict(some_data))
print("Метки:", list(some_diagnosis))
# Out:
# Прогнозы: [ 1.29521991  0.9678551   0.57196522  1.56461114 -0.17866148]
# Метки: [1, 1, 1, 1, 0]
